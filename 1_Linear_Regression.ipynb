# %% [markdown]
# **1. Linear Regression - coefficient, intercept, RMSE & r2**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
data = pd.read_csv('Advertising.csv', index_col=0) # Change Path
data.head()
data.columns = ['TV','Sales']

# %%
data
# Out:
#         TV  Sales
# 1    230.1   22.1
# 2     44.5   10.4
# 3     17.2    9.3
# 4    151.5   18.5
# 5    180.8   12.9
# ..     ...    ...
# 196   38.2    7.6
# 197   94.2    9.7
# 198  177.0   12.8
# 199  283.6   25.5
# 200  232.1   13.4
#
# [200 rows x 2 columns]

# %%
data.shape
# Out:
# (200, 2)

# %%
X = data[['TV']]
X
# Out:
#         TV
# 1    230.1
# 2     44.5
# 3     17.2
# 4    151.5
# 5    180.8
# ..     ...
# 196   38.2
# 197   94.2
# 198  177.0
# 199  283.6
# 200  232.1
#
# [200 rows x 1 columns]

# %%
y = data.Sales
y
# Out:
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
lm = LinearRegression()
lm.fit(X, y)

print(lm.intercept_)
print(lm.coef_)
# Out:
# 7.032593549127695
# [0.04753664]

# %%
X_new = pd.DataFrame({'TV': [230.1]})
X_new.head()
# Out:
#       TV
# 0  230.1

# %%
lm.predict(X_new)
# Out:
# array([17.97077451])

# %%
data['TV'].min()
# Out:
# 0.7

# %%
X_new = pd.DataFrame({'TV': [data['TV'].min(), data['TV'].max()]})
X_new.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([ 7.0658692 , 21.12245377])

# %%
data.plot(kind='scatter', x='TV', y='Sales')
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
predictions = lm.predict(X)
print(sqrt(mean_squared_error(y, predictions)))
# Out:
# 3.2423221486546887

# %%
r2 = r2_score(y, predictions)
r2
# Out:
# 0.611875050850071
